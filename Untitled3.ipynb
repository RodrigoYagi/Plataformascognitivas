# %% [markdown]
# Rodrigo Yagi Nakamura 23011254

# %%
import requests

# %%
n = input("Digite o ultimo número do RA: ")
print(n)
# Out:
# Digite o ultimo número do RA: 4
# 4

# %% [markdown]
# 2 Se sua camera for utilizada por mais de um robô, você poderá escolher que a 3 Informe qual camerâ será utilizada(Nome dele).
#
# Siga a tabela abaixo:
# 1 - FHAZ
# 2 - RHAZ
# 3 - MAST
# 4 - CHEMCAM
# 5 - MAHLI
# 6 - MARDI
# 7 - NAVCAM
# 8 - PANCAM
# 9 & 0 - MINITES

# %% [markdown]
# Digite o nome da sua camerâ: FHAZ

# %%
robo_entrada = int(input("FHAZ: "))
dia = int(input("Dia: "))
mês = int(input("Mês: "))
ano = int(input("Ano: "))
print(dia, mês, ano)
# Out:
# FHAZ: 2
# Dia: 22
# Mês: 09
# Ano: 2010
# 22 9 2010

# %%
resposta = requests.get(f"https://api.nasa.gov/mars-photos/api/v1/rovers/Spirit/photos?sol=100&page=2&api_key=DEMO_KEY")
print(resposta)
resposta.json()
# Out:
# <Response [200]>
# {'photos': [{'id': 317161,
#    'sol': 100,
#    'camera': {'id': 29,
#     'name': 'NAVCAM',
#     'rover_id': 7,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'http://mars.nasa.gov/mer/gallery/all/2/n/100/2N135241174EFF2702P1959R0M1-BR.JPG',
#    'earth_date': '2004-04-15',
#    'rover': {'id': 7,
#     'name': 'Spirit',
#     'landing_date': '2004-01-04',
#     'launch_date': '2003-06-10',
#     'status': 'complete',
#     'max_sol': 2208,
#     'max_date': '2010-03-21',
#     'total_photos': 124550,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'PANCAM', 'full_name': 'Panoramic Camera'},
#      {'name': 'MINITES',
#       'full_name': 'Miniature Thermal Emission Spectrometer (Mini-TES)'},
#      {'name': 'ENTRY', 'full_name': 'Entry, Descent, and Landing Camera'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
# ...
